# %%
n1 = str(3)

# %%
print(n1)
# Out:
# 3

# %%
import random

# %%
slide_id = round((random.random()*10))%5+1

# %%
slide_id
# Out:
# 5

# %%
case = round((random.random()*10))%6+1

# %%
case
# Out:
# 2

# %%
day = round((random.random()*10))%7

# %%
duration = round((random.random()*100000))%20000

# %%
duration
# Out:
# 14932

# %%
qquery = "insert into slide(slide_id, case, duration, day) values("+str(slide_id)+","+str(case)+","+str(duration)+","+str(day)+");"

# %%
qquery
# Out:
# 'insert into slide(slide_id, case, duration, day) values(5,2,14932,1);'

# %%
for i in range(0, 1000):
    slide_id = round((random.random()*10))%5+1
    case = round((random.random()*10))%6+1
    day = round((random.random()*10))%7
    duration = round((random.random()*100000))%20000
    startTime ="2020-11-"+str(round(day+1+7*((random.random()*10)%3)))+"-"+str(round(random.random()*100)%12+9)+"-"+str(round((random.random()*100))%60)+"-"+str((round(random.random()*100))%60)+"."+str(round(random.random()*1000000));
    qquery = "insert into slides(\"slides_id\", \"case\", \"duration\", \"day\", \"startTime\") values("+str(slide_id)+","+str(case)+","+str(duration)+","+str(day)+","+str(startTime)+");"
    print(qquery)
# Out:
# insert into slides("slides_id", "case", "duration", "day", "startTime") values(3,2,13685,4,2020-11-23-11-54-20.812737);
# insert into slides("slides_id", "case", "duration", "day", "startTime") values(3,3,9911,2,2020-11-14-17-34-33.479210);
# insert into slides("slides_id", "case", "duration", "day", "startTime") values(4,2,11605,6,2020-11-24-17-59-17.33487);
# insert into slides("slides_id", "case", "duration", "day", "startTime") values(1,5,11937,2,2020-11-21-20-1-22.38088);
# insert into slides("slides_id", "case", "duration", "day", "startTime") values(2,4,16334,4,2020-11-15-10-20-37.860440);
# insert into slides("slides_id", "case", "duration", "day", "startTime") values(2,5,6460,6,2020-11-16-14-31-27.931139);
# insert into slides("slides_id", "case", "duration", "day", "startTime") values(3,5,1566,2,2020-11-9-14-10-28.836502);
# insert into slides("slides_id", "case", "duration", "day", "startTime") values(5,2,19108,0,2020-11-2-10-12-40.826179);
# ...

# %%
str(round((day+1)+7*(random.random()%4)))
# Out:
# '4'

# %%
for i in range(0, 1000):
    print(str(round((round((random.random()*10))%7+1)+7*((random.random()*10)%3))))
# Out:
# 13
# 16
# 11
# 18
# 22
# 7
# 4
# 5
# 17
# 12
# 16
# 12
# 21
# 21
# 24
# 13
# 17
# 20
# 1
# 21
# 15
# 17
# 10
# 15
# 23
# 12
# 18
# 13
# 11
# 8
# 11
# 3
# 15
# 12
# 23
# 8
# 20
# 11
# 10
# 10
# 18
# 4
# 14
# 24
# 14
# 18
# 8
# 9
# 22
# 13
# 18
# 18
# 9
# 7
# 22
# 4
# 14
# 10
# 21
# 11
# 14
# 7
# 20
# 6
# 16
# 21
# 18
# 11
# 13
# 13
# 19
# 18
# 6
# 7
# 6
# 16
# 5
# 3
# 13
# 7
# 5
# 27
# 14
# 18
# 9
# 20
# 5
# 20
# 18
# 7
# 19
# 11
# 13
# 16
# 19
# 23
# 13
# 1
# 4
# 9
# 8
# 9
# 7
# 16
# 8
# 7
# 3
# 20
# 23
# 17
# 10
# 12
# 18
# 21
# 20
# 22
# 4
# 15
# 24
# 18
# 8
# 12
# 13
# 11
# 23
# 10
# 13
# 20
# 7
# 26
# 8
# 8
# 6
# 4
# 10
# 15
# 8
# 14
# 10
# 4
# 9
# 23
# 3
# 7
# 21
# 20
# 10
# 17
# 19
# 7
# 21
# 19
# 23
# 15
# 16
# 15
# 2
# 9
# 12
# 23
# 6
# 8
# 3
# 27
# 11
# 16
# 23
# 21
# 11
# 12
# 11
# 21
# 4
# 6
# 6
# 9
# 8
# 21
# 6
# 8
# 11
# 25
# 9
# 7
# 23
# 4
# 10
# 2
# 16
# 4
# 16
# 22
# 10
# 13
# 9
# 10
# 4
# 13
# 10
# 10
# 10
# 26
# 20
# 21
# 18
# 13
# 13
# 3
# 8
# 17
# 21
# 3
# 4
# 16
# ...

# %%
startTime ="2020-11-"+str(round((random.random()*10)%7+1+7*((random.random()*10)%3)))+"-"+str(round(random.random()*100)%12+9)+"-"+str(round((random.random()*100))%60)+"-"+str((round(random.random()*100))%60)+"."+str(round(random.random()*1000000));
print(startTime)
print()
# Out:
# 2020-11-19-15-20-26.254439

# %%
random.random()
# Out:
# 0.9633754604204562

# %%
str(round(random.random()*1000000))
# Out:
# '78202'

# %%
str((round(random.random()*100))%60)
# Out:
# '25'

# %%
str(round((random.random()*100))%60)
# Out:
# '2'

# %%
for i in range(0, 1000):

    print(str(round((random.random()*10)%7+1+7*((random.random()*10)%3))))
# Out:
# 24
# 23
# 21
# 16
# 23
# 21
# 5
# 13
# 11
# 10
# 7
# 14
# 17
# 10
# 19
# 7
# 4
# 15
# 17
# 14
# 23
# 15
# 17
# 14
# 24
# 25
# 16
# 15
# 15
# 27
# 6
# 2
# 18
# 25
# 5
# 17
# 8
# 13
# 12
# 25
# 17
# 5
# 17
# 5
# 8
# 16
# 9
# 2
# 10
# 13
# 22
# 14
# 11
# 24
# 10
# 22
# 11
# 6
# 13
# 19
# 15
# 16
# 22
# 23
# 11
# 12
# 15
# 6
# 8
# 10
# 19
# 15
# 15
# 9
# 17
# 5
# 7
# 4
# 12
# 11
# 22
# 4
# 8
# 13
# 15
# 25
# 5
# 23
# 9
# 19
# 16
# 11
# 5
# 10
# 26
# 22
# 22
# 16
# 21
# 9
# 11
# 13
# 5
# 18
# 18
# 9
# 13
# 6
# 4
# 8
# 21
# 12
# 10
# 8
# 16
# 6
# 11
# 9
# 11
# 19
# 8
# 8
# 7
# 11
# 13
# 14
# 7
# 8
# 11
# 10
# 20
# 7
# 8
# 21
# 18
# 6
# 17
# 17
# 16
# 23
# 4
# 8
# 8
# 19
# 7
# 22
# 19
# 6
# 24
# 23
# 18
# 10
# 18
# 20
# 5
# 4
# 18
# 19
# 19
# 14
# 14
# 22
# 16
# 8
# 17
# 5
# 16
# 8
# 3
# 9
# 13
# 11
# 17
# 9
# 3
# 22
# 21
# 9
# 17
# 11
# 3
# 16
# 16
# 22
# 15
# 13
# 10
# 9
# 20
# 4
# 6
# 8
# 12
# 23
# 20
# 7
# 24
# 20
# 20
# 10
# 19
# 5
# 9
# 16
# 12
# 12
# 22
# 7
# 9
# 3
# 19
# 10
# 20
# ...

# %%
    startTime ="2020-11-"+str(day+1+7*((random.random()*10)%3))+"-"+str(round(random.random()*100)%12+9)+"-"+str(round((random.random()*100))%60)+"-"+str((round(random.random()*100))%60)+"."+str(round(random.random()*1000000));
